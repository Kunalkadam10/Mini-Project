# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Kunal\OneDrive\Desktop\jupyter\shopping_behavior_updated.csv')

# %%
df.head(50)
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male         Blouse     Clothing
# 1             2   19   Male        Sweater     Clothing
# 2             3   50   Male          Jeans     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male         Blouse     Clothing
# 5             6   46   Male       Sneakers     Footwear
# 6             7   63   Male          Shirt     Clothing
# 7             8   27   Male         Shorts     Clothing
# 8             9   26   Male           Coat    Outerwear
# 9            10   57   Male        Handbag  Accessories
# 10           11   53   Male          Shoes     Footwear
# 11           12   30   Male         Shorts     Clothing
# 12           13   61   Male           Coat    Outerwear
# 13           14   65   Male          Dress     Clothing
# 14           15   64   Male           Coat    Outerwear
# 15           16   64   Male          Skirt     Clothing
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
pd.get_dummies(df)
# Out:
#       Customer ID  Age  Purchase Amount (USD)  Review Rating  \
# 0               1   55                     53            3.1
# 1               2   19                     64            3.1
# 2               3   50                     73            3.1
# 3               4   21                     90            3.5
# 4               5   45                     49            2.7
# ...           ...  ...                    ...            ...
# 3895         3896   40                     28            4.2
# 3896         3897   52                     49            4.5
# 3897         3898   46                     33            2.9
# 3898         3899   44                     77            3.8
# 3899         3900   52                     81            3.1
#
#       Previous Purchases  Gender_Female  Gender_Male  Item Purchased_Backpack  \
# 0                     14          False         True                    False
# ...

# %%
df['Age'].max()
df['Age'].min()
# Out:
# np.int64(18)

# %%
bins = [0,20,40,60,80]
labels = ['0-20','21-40','41-60','61-80']
df['Age_group'] = pd.cut(df['Age'] , bins = bins , labels = labels , include_lowest = True )

# %%
df['Age_group'].value_counts().sort_index()
# Out:
# Age_group
# 0-20      212
# 21-40    1462
# 41-60    1503
# 61-80     723
# Name: count, dtype: int64

# %%
df['Age'].plot(kind = 'hist' , bins = 8)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %%
counts = df['Category'].value_counts()
counts
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
print(f"Clothing sells {counts['Clothing']} times, Footwear sells {counts['Footwear']} times")
# Out:
# Clothing sells 1737 times, Footwear sells 599 times

# %%
df['Item Purchased'].value_counts().sort_values(ascending = False).nlargest()
# Out:
# Item Purchased
# Blouse     171
# Pants      171
# Jewelry    171
# Shirt      169
# Dress      166
# Name: count, dtype: int64

# %%
location_with_highest_revenue = df.groupby('Location')['Purchase Amount (USD)'].sum().sort_values(ascending = False).head(1)

# %%
location_with_highest_revenue
# Out:
# Location
# Montana    5784
# Name: Purchase Amount (USD), dtype: int64

# %%
avg_amt_category = df.groupby('Category')['Purchase Amount (USD)'].mean()

# %%
avg_amt_category
# Out:
# Category
# Accessories    59.838710
# Clothing       60.025331
# Footwear       60.255426
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
sub_status = df['Subscription Status'].value_counts()

# %%
sub_status.plot(kind = 'pie',  autopct = '1%.1f%%' )
# Out:
# <Axes: ylabel='count'>

# %%
df.groupby('Subscription Status')['Purchase Amount (USD)'].mean()
# Out:
# Subscription Status
# No     59.865121
# Yes    59.491928
# Name: Purchase Amount (USD), dtype: float64

# %%
df['Frequency of Purchases'].unique()
# Out:
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months'], dtype=object)

# %%
counts = df['Frequency of Purchases'].value_counts()

# %%
counts.index = [ '3M','Annually' ,'Quart' ,'M','Bi-Weekly  ' ,'Fortnightly','Weekly' ]

# %%
counts.plot(kind = 'line')
# Out:
# <Axes: >

# %%
df.groupby('Review Rating')['Purchase Amount (USD)'].mean().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Review Rating'>

# %%
df.groupby('Category')['Purchase Amount (USD)'].sum().plot(kind = 'line')
# Out:
# <Axes: xlabel='Category'>

# %%
df['high_val_customer'] = df['Previous Purchases'].apply(lambda x : 1 if x > 20 else 0)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 1                        64          Maine    L     Maroon  Winter  ...
# ...

# %%
df['High_Value_Customer'] = df['Previous Purchases'] > 20

# %%
df[df['High_Value_Customer']]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# 6               7   63    Male          Shirt     Clothing
# 10             11   53    Male          Shoes     Footwear
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 2                        73  Massachusetts    S     Maroon  Spring  ...
# 3                        90   Rhode Island    M     Maroon  Spring  ...
# ...

# %%
season_map = {'Winter': 1, 'Spring': 2, 'Summer': 3, 'Autumn': 4}

# %%
# Fill NaN with a number (e.g., 0) before converting
df['Season_no'] = df['Season'].map(season_map).fillna(0).astype(int)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 1                        64          Maine    L     Maroon  Winter  ...
# ...

# %%
df[['Customer ID' , 'Purchase Amount (USD)' ,'Age']].nlargest(50 , 'Purchase Amount (USD)')
# Out:
#       Customer ID  Purchase Amount (USD)  Age
# 42             43                    100   20
# 95             96                    100   37
# 193           194                    100   36
# 204           205                    100   24
# 243           244                    100   25
# 248           249                    100   47
# 455           456                    100   54
# 518           519                    100   24
# 581           582                    100   32
# 615           616                    100   67
# 769           770                    100   52
# 861           862                    100   46
# 1208         1209                    100   20
# 1300         1301                    100   67
# 1405         1406                    100   33
# 1412         1413                    100   25
# 1421         1422                    100   68
# 1456         1457                    100   59
# 1479         1480                    100   48
# ...

# %%
max_purchase = df['Purchase Amount (USD)'].max()
df[df['Purchase Amount (USD)'] == max_purchase]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 42             43   20    Male           Coat    Outerwear
# 95             96   37    Male       Sneakers     Footwear
# 193           194   36    Male           Belt  Accessories
# 204           205   24    Male       Sneakers     Footwear
# 243           244   25    Male        Jewelry  Accessories
# 248           249   47    Male           Belt  Accessories
# 455           456   54    Male         Blouse     Clothing
# 518           519   24    Male         Blouse     Clothing
# 581           582   32    Male        Sweater     Clothing
# 615           616   67    Male        Sandals     Footwear
# 769           770   52    Male          Socks     Clothing
# 861           862   46    Male          Skirt     Clothing
# 1208         1209   20    Male          Boots     Footwear
# 1300         1301   67    Male        T-shirt     Clothing
# 1405         1406   33    Male          Socks     Clothing
# ...

# %%
df.groupby('Category')['Purchase Amount (USD)'].mean().sort_values(ascending = False).head(1)
# Out:
# Category
# Footwear    60.255426
# Name: Purchase Amount (USD), dtype: float64

# %%
df.groupby(['Season' , 'Item Purchased']).size().sort_values(ascending = False)
# Out:
# Season  Item Purchased
# Fall    Jacket            54
# Spring  Sweater           52
# Winter  Sunglasses        52
#         Pants             51
# Summer  Pants             50
#                           ..
#         Skirt             28
#         Sweater           28
# Spring  Hat               27
# Fall    Shoes             26
# Winter  Backpack          25
# Length: 100, dtype: int64

# %%
df['Payment Method'].value_counts().sort_values(ascending = False).head(1)
# Out:
# Payment Method
# PayPal    677
# Name: count, dtype: int64

# %%
df.groupby('Subscription Status')['Purchase Amount (USD)'].mean()
# Out:
# Subscription Status
# No     59.865121
# Yes    59.491928
# Name: Purchase Amount (USD), dtype: float64
